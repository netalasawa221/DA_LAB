# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic=pd.read_csv("/kaggle/input/titanic/train.csv")
titanic.head()
titanic.shape

# %%
titanic.head()

# %%
titanic.corr()

# %%
sns.displot(data=titanic,x="Survived",hue="Pclass",palette="dark")

# %%
sns.heatmap(titanic.isnull(),yticklabels=False,cbar=False,cmap='magma')

# %%
sns.countplot(x="Survived",hue="Sex",data=titanic)

# %%
sns.countplot(x="Survived",hue="SibSp",data=titanic)

# %%
sns.barplot(data=titanic,x="Survived",y="Fare")

# %%
sns.boxplot(data=titanic,x="Pclass",y="Age")

# %%
def agefac(cols):
    Age=cols[0]
    Pclass=cols[1]
    
    if pd.isnull(Age):
        if Pclass == 1:
            return 38
        elif Pclass ==2:
            return 30
        else:
            return 24
    else:
        return Age

# %%
titanic["Age"]=titanic[["Age","Pclass"]].apply(agefac,axis=1)
titanic.shape

# %%
sns.heatmap(titanic.isnull(),yticklabels=False,cbar=False,cmap='magma')

# %%
titanic=titanic.drop(["Cabin","Name","Ticket"],axis=1)

# %%
titanic.dropna(inplace=True)
titanic.shape

# %%
sns.heatmap(titanic.isnull(),yticklabels=False,cbar=False,cmap='magma')

# %%
titanic.shape

# %%
Sex=pd.get_dummies(titanic["Sex"],drop_first=True)
Sex

# %%
Embarked=pd.get_dummies(titanic["Embarked"],drop_first=True)
Embarked

# %%
titanic=titanic.drop(["Sex","Embarked"],axis=1)

# %%
titanic=pd.concat([titanic,Sex,Embarked],axis=1)

# %%
titanic.head()

# %%
x=titanic.iloc[:,[0,2,3,4,5,6,7,8,9]]
y=titanic.iloc[:,[1]]

# %%
x

# %%
y

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=90)

# %%
x_train

# %%
x_test

# %%
y_train

# %%
y_test

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0)
classifier.fit(x_train,y_train)

# %%
print(classifier.predict([[12,2,43.0,0,1,34.5674,0,1,0]]))

# %%
y_pred=classifier.predict(x_test)

# %%
x_test

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %%
logreg_data = pd.read_csv("/kaggle/input/titanic/test.csv")

# %%
logreg_data

# %%
logreg_data.shape

# %%
logreg_data.info()

# %%
logreg_data["Age"]=logreg_data[["Age","Pclass"]].apply(agefac,axis=1)
logreg_data.shape

# %%
logreg_data=logreg_data.drop(["Cabin","Name","Ticket"],axis=1)

# %%
logreg_data['Fare'].fillna(np.mean(titanic['Fare']),inplace = True)
logreg_data.shape

# %%
sns.heatmap(logreg_data.isnull(),yticklabels=False,cbar=False,cmap='magma')

# %%
Sex=pd.get_dummies(logreg_data["Sex"],drop_first=True)
Sex

# %%
Embarked=pd.get_dummies(logreg_data["Embarked"],drop_first=True)
Embarked

# %%
logreg_data=logreg_data.drop(["Sex","Embarked"],axis=1)

# %%
logreg_data=pd.concat([logreg_data,Sex,Embarked],axis=1)

# %%
logreg_data.shape

# %%
logreg_data.shape

# %%
logreg_data.head()

# %%
logreg_data

# %%
logreg_data.shape

# %%
y_pred.sum()

# %%
y_prediction = classifier.predict(logreg_data)
logreg_data.insert((logreg_data.shape[1]),'Survived',y_prediction)
logreg_data=logreg_data.drop(["Pclass","Age","SibSp","Parch","Fare","male","Q","S"],axis=1)
logreg_data.to_csv('submission.csv')
logreg_data.shape

# %%
logreg_data
